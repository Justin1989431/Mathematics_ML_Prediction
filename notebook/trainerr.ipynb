# %%
# prompt: mount google drive and read data_math.xlsx

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Replace 'your_file_path' with the actual path to your Excel file in Google Drive
file_path = '/content/drive/My Drive/data_math.xlsx'

try:
  df = pd.read_excel(file_path)
  print(df.head())
except FileNotFoundError:
  print(f"Error: File not found at {file_path}. Please check the file path.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Mounted at /content/drive
#                                   school   sex   age Pstatus  Mother_edu  \
# 0          Conventional Secondary School  Male  34.0       T         1.0
# 1  Community Day Secondary School (CDSS)  Male  19.0       T         1.0
# 2  Community Day Secondary School (CDSS)  Male  19.0       T         3.0
# 3  Community Day Secondary School (CDSS)  Male  19.0       T         2.0
# 4  Community Day Secondary School (CDSS)  Male  18.0       T         2.0
#
#    Father_edu     Mjob      Fjob  traveltime  Peerpractice  ...  goals  \
# 0         2.0  at_home     other         1.0           1.0  ...    yes
# 1         1.0    other     other         3.0           2.0  ...    yes
# 2         3.0   health     other         3.0           1.0  ...     no
# 3         3.0  at_home  services         3.0           1.0  ...     no
# 4         2.0  at_home     other         3.0           1.0  ...     no
#
# ...

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set style of visualization
sns.set_style("whitegrid")
sns.set_palette("RdBu")

# %%
df.head()
# Out:
#                                   school   sex   age Pstatus  Mother_edu  \
# 0          Conventional Secondary School  Male  34.0       T         1.0
# 1  Community Day Secondary School (CDSS)  Male  19.0       T         1.0
# 2  Community Day Secondary School (CDSS)  Male  19.0       T         3.0
# 3  Community Day Secondary School (CDSS)  Male  19.0       T         2.0
# 4  Community Day Secondary School (CDSS)  Male  18.0       T         2.0
#
#    Father_edu     Mjob      Fjob  traveltime  Peerpractice  ...  goals  \
# 0         2.0  at_home     other         1.0           1.0  ...    yes
# 1         1.0    other     other         3.0           2.0  ...    yes
# 2         3.0   health     other         3.0           1.0  ...     no
# 3         3.0  at_home  services         3.0           1.0  ...     no
# 4         2.0  at_home     other         3.0           1.0  ...     no
#
#   Mathteachers XulResources EnglishScore teachingmethod absences  MathScore1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   school          1174 non-null   object
#  1   sex             1174 non-null   object
#  2   age             1173 non-null   float64
#  3   Pstatus         1174 non-null   object
#  4   Mother_edu      959 non-null    float64
#  5   Father_edu      1008 non-null   float64
#  6   Mjob            1049 non-null   object
#  7   Fjob            1023 non-null   object
#  8   traveltime      1021 non-null   float64
#  9   Peerpractice    1015 non-null   float64
#  10  studytime       984 non-null    float64
#  11  famsup          999 non-null    object
#  12  Affordfees      1012 non-null   object
#  13  goals           1040 non-null   object
#  14  Mathteachers    1072 non-null   object
#  15  XulResources    1044 non-null   object
#  16  EnglishScore    1174 non-null   float64
# ...

# %%
df.isna().sum() / df.shape[0]
# Out:
# school            0.000000
# sex               0.000000
# age               0.000852
# Pstatus           0.000000
# Mother_edu        0.183135
# Father_edu        0.141397
# Mjob              0.106474
# Fjob              0.128620
# traveltime        0.130324
# Peerpractice      0.135434
# studytime         0.161840
# famsup            0.149063
# Affordfees        0.137990
# goals             0.114140
# Mathteachers      0.086882
# XulResources      0.110733
# EnglishScore      0.000000
# teachingmethod    0.000000
# absences          0.000000
# MathScore1        0.000000
# MathScore2        0.000000
# MathScore3        0.000000
# Average           0.000000
# dtype: float64

# %%
# prompt: drop column pstatus

if 'Pstatus' in df.columns:
    df = df.drop('Pstatus', axis=1)
    print("Column 'pstatus' dropped successfully.")
else:
    print("Column 'pstatus' not found in the DataFrame.")

print(df.head())
# Out:
# Column 'pstatus' dropped successfully.
#                                   school   sex   age  Mother_edu  Father_edu  \
# 0          Conventional Secondary School  Male  34.0         1.0         2.0
# 1  Community Day Secondary School (CDSS)  Male  19.0         1.0         1.0
# 2  Community Day Secondary School (CDSS)  Male  19.0         3.0         3.0
# 3  Community Day Secondary School (CDSS)  Male  19.0         2.0         3.0
# 4  Community Day Secondary School (CDSS)  Male  18.0         2.0         2.0
#
#       Mjob      Fjob  traveltime  Peerpractice  studytime  ... goals  \
# 0  at_home     other         1.0           1.0        4.0  ...   yes
# 1    other     other         3.0           2.0        2.0  ...   yes
# 2   health     other         3.0           1.0        2.0  ...    no
# 3  at_home  services         3.0           1.0        2.0  ...    no
# 4  at_home     other         3.0           1.0        1.0  ...    no
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder from sklearn.preprocessing

df = pd.DataFrame(df)

# List of columns to encode
columns_to_encode = [
    "sex", "school", "Mjob", "Fjob", "famsup", "goals", "Mathteachers",
    "XulResources", "teachingmethod", "Affordfees"
]

# Initialize LabelEncoder
encoder = LabelEncoder()

# Encode each specified column
for column in columns_to_encode:
    df[column] = encoder.fit_transform(df[column])

# Display the encoded DataFrame
print(df)
# Out:
#       school  sex   age  Mother_edu  Father_edu  Mjob  Fjob  traveltime  \
# 0          1    1  34.0         1.0         2.0     1     2         1.0
# 1          0    1  19.0         1.0         1.0     3     2         3.0
# 2          0    1  19.0         3.0         3.0     2     2         3.0
# 3          0    1  19.0         2.0         3.0     1     4         3.0
# 4          0    1  18.0         2.0         2.0     1     2         3.0
# ...      ...  ...   ...         ...         ...   ...   ...         ...
# 1169       0    1  17.0         2.0         3.0     2     2         3.0
# 1170       0    1  18.0         2.0         2.0     3     4         1.0
# 1171       1    0  17.0         2.0         2.0     5     4         2.0
# 1172       2    0  18.0         NaN         4.0     5     2         3.0
# 1173       1    0  21.0         2.0         2.0     4     2         3.0
#
#       Peerpractice  studytime  ...  goals  Mathteachers  XulResources  \
# ...

# %%
df.head()
# Out:
#    school  sex   age  Mother_edu  Father_edu  Mjob  Fjob  traveltime  \
# 0       1    1  34.0         1.0         2.0     1     2         1.0
# 1       0    1  19.0         1.0         1.0     3     2         3.0
# 2       0    1  19.0         3.0         3.0     2     2         3.0
# 3       0    1  19.0         2.0         3.0     1     4         3.0
# 4       0    1  18.0         2.0         2.0     1     2         3.0
#
#    Peerpractice  studytime  ...  goals  Mathteachers  XulResources  \
# 0           1.0        4.0  ...      1             1             1
# 1           2.0        2.0  ...      1             1             1
# 2           1.0        2.0  ...      0             1             1
# 3           1.0        2.0  ...      0             1             1
# 4           1.0        1.0  ...      0             1             1
#
#    EnglishScore  teachingmethod  absences  MathScore1  MathScore2  MathScore3  \
# ...

# %%
df.shape
# Out:
# (1174, 22)

# %%
df.duplicated().any()
# Out:
# True

# %%
df.describe()
# Out:
#             school          sex          age  Mother_edu   Father_edu  \
# count  1174.000000  1174.000000  1173.000000  959.000000  1008.000000
# mean      0.352641     0.410562    17.402387    2.047967     2.968254
# std       0.652888     0.492145     2.029659    0.703253     0.840263
# min       0.000000     0.000000    11.000000    0.000000     0.000000
# 25%       0.000000     0.000000    17.000000    2.000000     2.000000
# 50%       0.000000     0.000000    18.000000    2.000000     3.000000
# 75%       1.000000     1.000000    18.000000    2.000000     4.000000
# max       2.000000     1.000000    34.000000    4.000000     4.000000
#
#               Mjob         Fjob   traveltime  Peerpractice   studytime  ...  \
# count  1174.000000  1174.000000  1021.000000   1015.000000  984.000000  ...
# mean      3.155026     3.270017     2.259549      1.683744    2.243902  ...
# std       1.925241     1.604928     0.765826      0.802782    0.751711  ...
# ...

# %%
# create function to visualized categorical column using count plot

def count_plot(column_name, hue = None, rotation = 0):
    """
    1) input : column name, column data type must be object or categorical
    3) output : cout plot using seaborn modules, unique values in x-axis and frequency in y-axis
    4) i use bar_label to show frequency of each unique values above each column in graph
    """
    graph = sns.countplot(x = column_name, data = df, hue = hue, order = df[column_name].value_counts().index)
    for container in graph.containers:
        graph.bar_label(container)


    plt.xticks(rotation = rotation)
    plt.show()

# %%
# create function that visualized numeric columns using box plot

def box_plot(x_axis = None, y_axis = None, hue = None, col = None):
    """
    input : x_axis, y_axis and hue column, column data type must be numeric in y_axis
    output : box plot to see distribution of column values such as min,max,mean,medien,std
    """
    sns.catplot(x = x_axis, y = y_axis, data = df, hue = hue, kind = "box", col = col)
    plt.xlabel(x_axis)
    plt.ylabel("FRQ")
    plt.show()

# %%
plt.figure(figsize = (13,10))
sns.heatmap(df.select_dtypes(exclude = object).corr(), annot = True, fmt = ".2f", linewidths = 0.2)
plt.show()

# %%
# import libraries to model

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

# %%
print(df.columns)
# Out:
# Index(['school', 'sex', 'age', 'Mother_edu', 'Father_edu', 'Mjob', 'Fjob',
#        'traveltime', 'Peerpractice', 'studytime', 'famsup', 'Affordfees',
#        'goals', 'Mathteachers', 'XulResources', 'EnglishScore',
#        'teachingmethod', 'absences', 'MathScore1', 'MathScore2', 'MathScore3',
#        'Average '],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
# import libraries to model

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score

Train = df.drop(columns = "Average")
Target = df["Average"]

# %%
df.sample(4)
# Out:
#       school  sex   age  Mother_edu  Father_edu  Mjob  Fjob  traveltime  \
# 679        0    0  21.0         NaN         2.0     1     2         1.0
# 812        0    1  18.0         3.0         3.0     5     4         3.0
# 570        0    0  14.0         2.0         NaN     2     1         2.0
# 1088       0    0  14.0         3.0         3.0     3     2         3.0
#
#       Peerpractice  studytime  ...  goals  Mathteachers  XulResources  \
# 679            NaN        3.0  ...      1             1             2
# 812            1.0        2.0  ...      1             0             1
# 570            1.0        3.0  ...      1             1             1
# 1088           2.0        3.0  ...      1             1             0
#
#       EnglishScore  teachingmethod  absences  MathScore1  MathScore2  \
# 679           17.0               1         4    8.568824        10.0
# 812            5.0               0         0    6.000000         5.0
# ...

# %%
print(df.columns)
# Out:
# Index(['school', 'sex', 'age', 'Mother_edu', 'Father_edu', 'Mjob', 'Fjob',
#        'traveltime', 'Peerpractice', 'studytime', 'famsup', 'Affordfees',
#        'goals', 'Mathteachers', 'XulResources', 'EnglishScore',
#        'teachingmethod', 'absences', 'MathScore1', 'MathScore2', 'MathScore3',
#        'Average'],
#       dtype='object')

# %%
Train = df.drop(columns = "Average")
Target = df["Average"]

# %%
Train.sample(3)
# Out:
#      school  sex   age  Mother_edu  Father_edu  Mjob  Fjob  traveltime  \
# 836       0    0  23.0         1.0         4.0     1     5         3.0
# 720       1    1  16.0         3.0         3.0     1     2         2.0
# 69        0    0  18.0         3.0         3.0     5     2         3.0
#
#      Peerpractice  studytime  ...  Affordfees  goals  Mathteachers  \
# 836           1.0        2.0  ...           1      1             1
# 720           3.0        3.0  ...           0      1             1
# 69            1.0        2.0  ...           1      1             1
#
#      XulResources  EnglishScore  teachingmethod  absences  MathScore1  \
# 836             1           7.0               1         0         8.0
# 720             1          13.0               0         7        14.0
# 69              0           7.0               0         0         6.0
#
#      MathScore2  MathScore3
# 836         6.0         7.0
# 720        17.0        19.0
# 69          7.0         6.0
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(Train, Target, test_size = 0.2, random_state = 42)

# %%
# see shape of splited data

print("x_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("x_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (939, 21)
# y_train shape:  (939,)
# x_test shape:  (235, 21)
# y_test shape:  (235,)

# %%
# create object from RandomForestRegressor

model = LinearRegression()

# %%
print(X_train.isnull().sum())
# Out:
# school              0
# sex                 0
# age                 0
# Mother_edu        171
# Father_edu        138
# Mjob                0
# Fjob                0
# traveltime        132
# Peerpractice      134
# studytime         154
# famsup              0
# Affordfees          0
# goals               0
# Mathteachers        0
# XulResources        0
# EnglishScore        0
# teachingmethod      0
# absences            0
# MathScore1          0
# MathScore2          0
# MathScore3          0
# dtype: int64

# %%
X_train = X_train.dropna()
y_train = y_train.loc[X_train.index]  # Drop corresponding rows in y_train

# %%
print(X_train.isnull().sum())
# Out:
# school            0
# sex               0
# age               0
# Mother_edu        0
# Father_edu        0
# Mjob              0
# Fjob              0
# traveltime        0
# Peerpractice      0
# studytime         0
# famsup            0
# Affordfees        0
# goals             0
# Mathteachers      0
# XulResources      0
# EnglishScore      0
# teachingmethod    0
# absences          0
# MathScore1        0
# MathScore2        0
# MathScore3        0
# dtype: int64

# %%
# fit model

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Calculate the score of the model on the training data

model.score(X_train, y_train)
# Out:
# 0.8714026361364793

# %%
# prompt: drop na values in X_test

X_test = X_test.dropna()
y_test = y_test.loc[X_test.index]  # Drop corresponding rows in y_test

# %%
predict = np.round(model.predict(X_test), decimals = 1)

# %%
pd.DataFrame({"Actual Performance" : y_test, "Predicted Performance" : predict})
# Out:
#       Actual Performance  Predicted Performance
# 208                   17                   16.7
# 811                    6                    5.6
# 1066                   7                    7.7
# 832                    8                    7.3
# 58                     6                    6.1
# ...                  ...                    ...
# 905                    9                    8.9
# 367                    4                    8.4
# 43                     7                    6.4
# 1166                  11                   11.7
# 135                   11                   11.3
#
# [151 rows x 2 columns]

# %%
plt.scatter(y_test, predict)
plt.show()

# %%
# see mean absolute error

mean_absolute_error(y_test,predict)
# Out:
# 0.5880794701986755

# %%
# see score

r2_score(y_test,predict)
# Out:
# 0.8984936923668032

# %%
# see coefficients values

model.coef_
# Out:
# array([-0.05265228,  0.01558532, -0.0713751 ,  0.02595225,  0.06731445,
#         0.01415122,  0.00362266,  0.03190696,  0.05540161,  0.07810765,
#         0.22867372, -0.21790307, -0.25894744, -0.13353965, -0.13596385,
#         0.04663554,  0.13086612,  0.01215362,  0.3560844 ,  0.29472475,
#         0.32086144])

# %%
# see y intercept

model.intercept_
# Out:
# 0.7880618545583911

# %%
X_test = X_test.dropna()
y_test = y_test.loc[X_test.index]

# %%
#Random forest

from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
rf_predictions = rf_model.predict(X_test)

# %%
#Gradient boosting

from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(random_state=42)
gb_model.fit(X_train, y_train)
gb_predictions = gb_model.predict(X_test)

# %%
#SVM
from sklearn.svm import SVR

svr_model = SVR()
svr_model.fit(X_train, y_train)
svr_predictions = svr_model.predict(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Function to evaluate models
def evaluate_model(y_true, y_pred, model_name):
    print(f"Results for {model_name}:")
    print("MAE:", mean_absolute_error(y_true, y_pred))
    print("MSE:", mean_squared_error(y_true, y_pred))
    print("R² Score:", r2_score(y_true, y_pred))
    print("-" * 40)

# Prepare models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "Support Vector Regression": SVR(),
}

# Fit models and evaluate
for name, model in models.items():
    model.fit(X_train, y_train)  # Train the model
    predictions = model.predict(X_test)  # Predict on the test set
    evaluate_model(y_test, predictions, name)
# Out:
# Results for Linear Regression:
# MAE: 0.5929498358997402
# MSE: 1.1215836785698456
# R² Score: 0.8976481275011564
# ----------------------------------------
# Results for Random Forest:
# MAE: 0.4545309050772626
# MSE: 0.9840861249080205
# R² Score: 0.9101956817765922
# ----------------------------------------
# Results for Gradient Boosting:
# MAE: 0.5540839103704714
# MSE: 1.3408137954233081
# R² Score: 0.8776419403598599
# ----------------------------------------
# Results for Support Vector Regression:
# MAE: 0.5870774719029661
# MSE: 1.228373525561425
# R² Score: 0.8879028530180342
# ----------------------------------------
